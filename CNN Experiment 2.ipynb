# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.datasets import cifar10, cifar100
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns
import cv2
import time
import pandas as pd
import os

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Check GPU availability
print("TensorFlow version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))

# Set memory growth to avoid OOM errors
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    for device in physical_devices:
        tf.config.experimental.set_memory_growth(device, True)
    print("Memory growth set to True")

# Function to load and preprocess CIFAR datasets
def load_and_preprocess_data(dataset='cifar10', validation_split=0.1):
    """
    Loads CIFAR-10 or CIFAR-100, creates a validation split,
    normalizes pixel values, and returns data and one-hot labels.
    """
    # Load the dataset
    if dataset == 'cifar10':
        (x_train, y_train), (x_test, y_test) = cifar10.load_data()
        num_classes = 10
    else:  # cifar100
        (x_train, y_train), (x_test, y_test) = cifar100.load_data(label_mode='fine')
        num_classes = 100

    # Create a validation set
    val_size = int(len(x_train) * validation_split)
    indices = np.random.permutation(len(x_train))
    train_indices, val_indices = indices[val_size:], indices[:val_size]

    x_val, y_val = x_train[val_indices], y_train[val_indices]
    x_train, y_train = x_train[train_indices], y_train[train_indices]

    # Convert data to float32 and normalize
    # IMPROVED: Use mean and std normalization instead of just dividing by 255
    x_train = x_train.astype('float32') / 255.0
    x_val = x_val.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # Calculate mean and std for better normalization
    mean = np.mean(x_train, axis=(0, 1, 2))
    std = np.std(x_train, axis=(0, 1, 2))

    # Apply normalization with mean and std
    x_train = (x_train - mean) / (std + 1e-7)
    x_val = (x_val - mean) / (std + 1e-7)
    x_test = (x_test - mean) / (std + 1e-7)

    # Print data ranges to verify normalization
    print(f"Training data range: {x_train.min():.4f} to {x_train.max():.4f}")
    print(f"Validation data range: {x_val.min():.4f} to {x_val.max():.4f}")
    print(f"Test data range: {x_test.min():.4f} to {x_test.max():.4f}")

    # Convert labels to one-hot encoding
    y_train = to_categorical(y_train, num_classes)
    y_val = to_categorical(y_val, num_classes)
    y_test = to_categorical(y_test, num_classes)

    print(f'Dataset: {dataset}')
    print(f'Training set shape: {x_train.shape}, {y_train.shape}')
    print(f'Validation set shape: {x_val.shape}, {y_val.shape}')
    print(f'Test set shape: {x_test.shape}, {y_test.shape}')

    return x_train, y_train, x_val, y_val, x_test, y_test, num_classes

# Create a data augmentation generator with improved augmentation parameters
def create_data_generator():
    """
    Returns an ImageDataGenerator with more diverse but not extreme augmentations
    """
    return ImageDataGenerator(
        rotation_range=10,        # Reduced from 15 to avoid too extreme transformations
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
        zoom_range=0.1,
        shear_range=0.05,         # Reduced from 0.1
        brightness_range=[0.9, 1.1],  # Less extreme brightness changes
        fill_mode='nearest'
    )

# Improved residual block function with BN->ReLU->Conv order (pre-activation)
def residual_block(x, filters, kernel_size=3, strides=1, block_name='res_block'):
    """
    Builds an improved residual block with pre-activation and identity mappings
    following ResNet v2 design principles.
    """
    # Save input for the skip connection
    shortcut = x
    input_filters = x.shape[-1]

    # Pre-activation (BN -> ReLU -> Conv) for better gradient flow
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Activation('relu', name=f'{block_name}_relu1')(x)

    # First convolution
    x = layers.Conv2D(
        filters,
        kernel_size=kernel_size,
        strides=strides,
        padding='same',
        kernel_initializer='he_normal',
        name=f'{block_name}_conv1'
    )(x)

    # Second pre-activation
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    x = layers.Activation('relu', name=f'{block_name}_relu2')(x)

    # Second convolution
    x = layers.Conv2D(
        filters,
        kernel_size=kernel_size,
        padding='same',
        kernel_initializer='he_normal',
        name=f'{block_name}_conv2'
    )(x)

    # Handle shortcut connection if dimensions change
    if strides > 1 or input_filters != filters:
        shortcut = layers.Conv2D(
            filters,
            kernel_size=1,
            strides=strides,
            padding='same',
            kernel_initializer='he_normal',
            name=f'{block_name}_shortcut_conv'
        )(shortcut)

    # Add the shortcut to the output (identity or projection shortcut)
    x = layers.Add(name=f'{block_name}_add')([shortcut, x])

    return x

# Build improved 5-block ResNet architecture
def build_improved_resnet(input_shape, num_classes):
    """
    Builds an improved 5-block ResNet architecture with better gradient flow
    and regularization.
    """
    # Input layer
    inputs = layers.Input(shape=input_shape, name='input_layer')

    # Initial processing
    x = layers.Conv2D(
        64, kernel_size=3, padding='same',
        kernel_initializer='he_normal',
        name='initial_conv'
    )(inputs)
    x = layers.BatchNormalization(name='initial_bn')(x)
    x = layers.Activation('relu', name='initial_relu')(x)

    # Block 1 - 64 filters (no downsampling)
    x = residual_block(x, filters=64, kernel_size=3, block_name='block1_res1')
    # Reduced dropout rate for early layers
    x = layers.Dropout(0.05, name='block1_dropout')(x)

    # Block 2 - 128 filters (with downsampling)
    x = residual_block(x, filters=128, kernel_size=3, strides=2, block_name='block2_res1')
    x = layers.Dropout(0.1, name='block2_dropout')(x)

    # Block 3 - 256 filters (with downsampling)
    x = residual_block(x, filters=256, kernel_size=3, strides=2, block_name='block3_res1')
    x = layers.Dropout(0.2, name='block3_dropout')(x)

    # Block 4 - 512 filters (with downsampling)
    x = residual_block(x, filters=512, kernel_size=3, strides=2, block_name='block4_res1')
    x = layers.Dropout(0.25, name='block4_dropout')(x)

    # Block 5 - 512 filters (no downsampling)
    x = residual_block(x, filters=512, kernel_size=3, block_name='block5_res1')
    x = layers.Dropout(0.3, name='block5_dropout')(x)

    # Global pooling and classification layers
    x = layers.GlobalAveragePooling2D(name='global_pool')(x)

    # Additional dense layer with L2 regularization
    x = layers.Dense(
        512,
        kernel_initializer='he_normal',
        kernel_regularizer=tf.keras.regularizers.l2(1e-4),
        name='dense1'
    )(x)
    x = layers.BatchNormalization(name='bn_dense')(x)
    x = layers.Activation('relu', name='relu_dense')(x)
    x = layers.Dropout(0.5, name='dropout_dense')(x)

    # Output layer
    outputs = layers.Dense(
        num_classes,
        activation='softmax',
        kernel_initializer='glorot_uniform',
        name='output'
    )(x)

    model = models.Model(inputs=inputs, outputs=outputs, name='cifar_resnet_5block_improved')
    return model

# Improved learning rate scheduler with gentler decay
def lr_scheduler(epoch, initial_lr=0.001, warmup_epochs=5):
    """
    Creates a learning rate schedule with warmup and gentler decay.
    """
    # Warmup phase
    if epoch < warmup_epochs:
        return initial_lr * ((epoch + 1) / warmup_epochs)

    # Decay phase - using cosine decay instead of step decay
    decay_epochs = 50  # Total expected training epochs
    decay_rate = 0.5 * (1 + np.cos(np.pi * (epoch - warmup_epochs) / (decay_epochs - warmup_epochs)))
    return initial_lr * decay_rate

# Improved training function
def train_model(dataset='cifar10', batch_size=128, epochs=100, fine_tune=False, model_path=None, save_dir='.'):
    """
    Trains or fine-tunes the improved ResNet model with better learning dynamics.
    """
    start_time = time.time()

    # Make sure save directory exists
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Load and preprocess data
    x_train, y_train, x_val, y_val, x_test, y_test, num_classes = load_and_preprocess_data(dataset)

    print("Data Statistics:")
    print(f"Training samples: {x_train.shape[0]}")
    print(f"Validation samples: {x_val.shape[0]}")
    print(f"Test samples: {x_test.shape[0]}")
    print(f"Data range: {x_train.min():.4f} to {x_train.max():.4f}")

    # Get class names
    if dataset == 'cifar10':
        class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
                       'dog', 'frog', 'horse', 'ship', 'truck']
    else:  # cifar100
        class_names = get_cifar100_class_names()

    # Build or load model
    if fine_tune and model_path and os.path.exists(model_path):
        print(f"Loading model from {model_path} for fine-tuning")
        try:
            model = models.load_model(model_path, compile=False)

            # If moving from cifar10 to cifar100, replace the output layer
            if dataset == 'cifar100' and model.output_shape[-1] != num_classes:
                print(f"Replacing output layer to match {num_classes} classes")
                x = model.layers[-2].output
                new_output = layers.Dense(
                    num_classes,
                    activation='softmax',
                    kernel_initializer='glorot_uniform',
                    name='new_output'
                )(x)
                model = models.Model(inputs=model.input, outputs=new_output)

        except Exception as e:
            print(f"Error during model loading: {e}")
            print("Building a new model instead...")
            model = build_improved_resnet(x_train.shape[1:], num_classes)
    else:
        print("Building a new improved ResNet model...")
        model = build_improved_resnet(x_train.shape[1:], num_classes)

    # Higher initial learning rate for better exploration
    initial_learning_rate = 0.01

    # Learning rate schedule function - use partial to pass the initial_lr
    from functools import partial
    lr_schedule = partial(
        lr_scheduler,
        initial_lr=initial_learning_rate,
        warmup_epochs=5
    )

    # Compile model with label smoothing
    loss_fn = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

    # Use SGD with momentum instead of Adam for better generalization
    optimizer = optimizers.SGD(
        learning_rate=initial_learning_rate,
        momentum=0.9,
        nesterov=True
    )

    model.compile(
        optimizer=optimizer,
        loss=loss_fn,
        metrics=['accuracy']
    )

    model.summary()

    print(f"\nTraining {dataset} with improved 5-block ResNet")
    print(f"Batch size: {batch_size}, Epochs: {epochs}")
    print(f"Initial learning rate: {initial_learning_rate}")

    # Callbacks
    callbacks_list = [
        callbacks.LearningRateScheduler(lr_schedule, verbose=1),
        callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=15,  # Increased patience
            restore_best_weights=True,
            verbose=1
        ),
        callbacks.ModelCheckpoint(
            filepath=os.path.join(save_dir, f'best_model_{dataset}_improved.keras'),
            monitor='val_accuracy',
            save_best_only=True,
            verbose=1
        ),
        # Add ReduceLROnPlateau for adaptive learning rate reduction
        callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5,
            min_lr=1e-6,
            verbose=1
        )
    ]

    # Data generator with augmentation
    datagen = create_data_generator()
    datagen.fit(x_train)

    # Training
    print("\nStarting training...")
    history = model.fit(
        datagen.flow(x_train, y_train, batch_size=batch_size),
        epochs=epochs,
        validation_data=(x_val, y_val),
        callbacks=callbacks_list,
        verbose=1
    )

    training_time = time.time() - start_time
    print(f"\nTraining completed in {training_time/60:.2f} minutes")

    # Evaluate on test set
    print("\nEvaluating model on test set...")
    test_loss, test_acc = model.evaluate(x_test, y_test, verbose=1)
    print(f"Test accuracy: {test_acc:.4f}")

    # Generate predictions
    y_pred = model.predict(x_test, verbose=1)
    y_true_classes = np.argmax(y_test, axis=1)
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Classification report
    print("\nClassification Report:")
    if dataset == 'cifar100':
        from collections import Counter
        most_common_classes = [cls for cls, _ in Counter(y_true_classes).most_common(20)]
        selected_class_names = [class_names[i] for i in most_common_classes]
        mask = np.isin(y_true_classes, most_common_classes)
        if np.any(mask):
            y_true_filtered = y_true_classes[mask]
            y_pred_filtered = y_pred_classes[mask]
            print(classification_report(
                y_true_filtered,
                y_pred_filtered,
                labels=most_common_classes,
                target_names=selected_class_names
            ))
    else:
        print(classification_report(y_true_classes, y_pred_classes, target_names=class_names))

    # Save model summary and metrics
    with open(os.path.join(save_dir, f'model_summary_{dataset}_improved.txt'), 'w') as f:
        model.summary(print_fn=lambda x: f.write(x + '\n'))

        f.write(f"\nDataset: {dataset}\n")
        f.write(f"Model: Improved 5-Block ResNet\n")
        f.write(f"Training time: {training_time/60:.2f} minutes\n\n")
        f.write(f"Test accuracy: {test_acc:.4f}\n")

    return model, history

# Get CIFAR-100 class names
def get_cifar100_class_names():
    return [
        'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
        'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
        'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
        'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
        'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
        'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
        'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
        'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
        'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
        'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
        'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
        'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
        'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
        'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
        'worm'
    ]

# Main execution
if __name__ == "__main__":
    # Save directory for models and results
    import os
    save_dir = './CIFAR_CNN_Improved'
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Train on CIFAR-10
    print("=== Training improved ResNet on CIFAR-10 ===")
    cifar10_model, _ = train_model(
        dataset='cifar10',
        batch_size=128,  # Increased batch size
        epochs=100,      # More epochs with earlier stopping
        save_dir=save_dir
    )

    # Fine-tune on CIFAR-100 using the best model from CIFAR-10 training
    print("\n=== Fine-tuning on CIFAR-100 ===")
    best_model_path = os.path.join(save_dir, 'best_model_cifar10_improved.keras')

    if os.path.exists(best_model_path):
        print(f"Using best model from {best_model_path} for fine-tuning")
        cifar100_model, _ = train_model(
            dataset='cifar100',
            batch_size=128,
            epochs=100,
            fine_tune=True,
            model_path=best_model_path,
            save_dir=save_dir
        )
    else:
        print(f"Best model file {best_model_path} not found. Training CIFAR-100 from scratch.")
        cifar100_model, _ = train_model(
            dataset='cifar100',
            batch_size=128,
            epochs=100,
            save_dir=save_dir
        )

    print("Training and evaluation completed!")
# Out:
# TensorFlow version: 2.18.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Memory growth set to True
# === Training improved ResNet on CIFAR-10 ===
# Training data range: -1.9896 to 2.1261
# Validation data range: -1.9896 to 2.1261
# Test data range: -1.9896 to 2.1261
# Dataset: cifar10
# Training set shape: (45000, 32, 32, 3), (45000, 10)
# Validation set shape: (5000, 32, 32, 3), (5000, 10)
# Test set shape: (10000, 32, 32, 3), (10000, 10)
# Data Statistics:
# Training samples: 45000
# Validation samples: 5000
# Test samples: 10000
# Data range: -1.9896 to 2.1261
# Building a new improved ResNet model...
# Model: "cifar_resnet_5block_improved"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 32, 32, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ initial_conv (Conv2D)     │ (None, 32, 32, 64)     │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ initial_bn                │ (None, 32, 32, 64)     │            256 │ initial_conv[0][0]     │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ initial_relu (Activation) │ (None, 32, 32, 64)     │              0 │ initial_bn[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_bn1           │ (None, 32, 32, 64)     │            256 │ initial_relu[0][0]     │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_relu1         │ (None, 32, 32, 64)     │              0 │ block1_res1_bn1[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_conv1         │ (None, 32, 32, 64)     │         36,928 │ block1_res1_relu1[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_bn2           │ (None, 32, 32, 64)     │            256 │ block1_res1_conv1[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_relu2         │ (None, 32, 32, 64)     │              0 │ block1_res1_bn2[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_conv2         │ (None, 32, 32, 64)     │         36,928 │ block1_res1_relu2[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_add (Add)     │ (None, 32, 32, 64)     │              0 │ initial_relu[0][0],    │
# │                           │                        │                │ block1_res1_conv2[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_dropout (Dropout)  │ (None, 32, 32, 64)     │              0 │ block1_res1_add[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_bn1           │ (None, 32, 32, 64)     │            256 │ block1_dropout[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_relu1         │ (None, 32, 32, 64)     │              0 │ block2_res1_bn1[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_conv1         │ (None, 16, 16, 128)    │         73,856 │ block2_res1_relu1[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_bn2           │ (None, 16, 16, 128)    │            512 │ block2_res1_conv1[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_relu2         │ (None, 16, 16, 128)    │              0 │ block2_res1_bn2[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_shortcut_conv │ (None, 16, 16, 128)    │          8,320 │ block1_dropout[0][0]   │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_conv2         │ (None, 16, 16, 128)    │        147,584 │ block2_res1_relu2[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_add (Add)     │ (None, 16, 16, 128)    │              0 │ block2_res1_shortcut_… │
# │                           │                        │                │ block2_res1_conv2[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_dropout (Dropout)  │ (None, 16, 16, 128)    │              0 │ block2_res1_add[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_res1_bn1           │ (None, 16, 16, 128)    │            512 │ block2_dropout[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_res1_relu1         │ (None, 16, 16, 128)    │              0 │ block3_res1_bn1[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_res1_conv1         │ (None, 8, 8, 256)      │        295,168 │ block3_res1_relu1[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_res1_bn2           │ (None, 8, 8, 256)      │          1,024 │ block3_res1_conv1[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_res1_relu2         │ (None, 8, 8, 256)      │              0 │ block3_res1_bn2[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_res1_shortcut_conv │ (None, 8, 8, 256)      │         33,024 │ block2_dropout[0][0]   │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_res1_conv2         │ (None, 8, 8, 256)      │        590,080 │ block3_res1_relu2[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_res1_add (Add)     │ (None, 8, 8, 256)      │              0 │ block3_res1_shortcut_… │
# │                           │                        │                │ block3_res1_conv2[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_dropout (Dropout)  │ (None, 8, 8, 256)      │              0 │ block3_res1_add[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_res1_bn1           │ (None, 8, 8, 256)      │          1,024 │ block3_dropout[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_res1_relu1         │ (None, 8, 8, 256)      │              0 │ block4_res1_bn1[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_res1_conv1         │ (None, 4, 4, 512)      │      1,180,160 │ block4_res1_relu1[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_res1_bn2           │ (None, 4, 4, 512)      │          2,048 │ block4_res1_conv1[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_res1_relu2         │ (None, 4, 4, 512)      │              0 │ block4_res1_bn2[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_res1_shortcut_conv │ (None, 4, 4, 512)      │        131,584 │ block3_dropout[0][0]   │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_res1_conv2         │ (None, 4, 4, 512)      │      2,359,808 │ block4_res1_relu2[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_res1_add (Add)     │ (None, 4, 4, 512)      │              0 │ block4_res1_shortcut_… │
# │                           │                        │                │ block4_res1_conv2[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4_dropout (Dropout)  │ (None, 4, 4, 512)      │              0 │ block4_res1_add[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_res1_bn1           │ (None, 4, 4, 512)      │          2,048 │ block4_dropout[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_res1_relu1         │ (None, 4, 4, 512)      │              0 │ block5_res1_bn1[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_res1_conv1         │ (None, 4, 4, 512)      │      2,359,808 │ block5_res1_relu1[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_res1_bn2           │ (None, 4, 4, 512)      │          2,048 │ block5_res1_conv1[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_res1_relu2         │ (None, 4, 4, 512)      │              0 │ block5_res1_bn2[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_res1_conv2         │ (None, 4, 4, 512)      │      2,359,808 │ block5_res1_relu2[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_res1_add (Add)     │ (None, 4, 4, 512)      │              0 │ block4_dropout[0][0],  │
# │                           │                        │                │ block5_res1_conv2[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5_dropout (Dropout)  │ (None, 4, 4, 512)      │              0 │ block5_res1_add[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_pool               │ (None, 512)            │              0 │ block5_dropout[0][0]   │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense1 (Dense)            │ (None, 512)            │        262,656 │ global_pool[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_dense                  │ (None, 512)            │          2,048 │ dense1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ relu_dense (Activation)   │ (None, 512)            │              0 │ bn_dense[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_dense (Dropout)   │ (None, 512)            │              0 │ relu_dense[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output (Dense)            │ (None, 10)             │          5,130 │ dropout_dense[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 9,894,922 (37.75 MB)
#  Trainable params: 9,888,778 (37.72 MB)
#  Non-trainable params: 6,144 (24.00 KB)
# Training cifar10 with improved 5-block ResNet
# Batch size: 128, Epochs: 100
# Initial learning rate: 0.01
#
# Starting training...
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.002.
# Epoch 1/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.2064 - loss: 2.5283
# Epoch 1: val_accuracy improved from -inf to 0.37200, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 75s 152ms/step - accuracy: 0.2065 - loss: 2.5278 - val_accuracy: 0.3720 - val_loss: 1.9169 - learning_rate: 0.0020
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.004.
# Epoch 2/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3233 - loss: 2.0567
# Epoch 2: val_accuracy improved from 0.37200 to 0.43400, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.3233 - loss: 2.0566 - val_accuracy: 0.4340 - val_loss: 1.8052 - learning_rate: 0.0040
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.006.
# Epoch 3/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3992 - loss: 1.8850
# Epoch 3: val_accuracy improved from 0.43400 to 0.43560, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.3993 - loss: 1.8849 - val_accuracy: 0.4356 - val_loss: 1.8252 - learning_rate: 0.0060
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.008.
# Epoch 4/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.4495 - loss: 1.7840
# Epoch 4: val_accuracy improved from 0.43560 to 0.46000, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.4495 - loss: 1.7840 - val_accuracy: 0.4600 - val_loss: 1.8661 - learning_rate: 0.0080
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.01.
# Epoch 5/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.4867 - loss: 1.7106
# Epoch 5: val_accuracy improved from 0.46000 to 0.53000, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.4867 - loss: 1.7105 - val_accuracy: 0.5300 - val_loss: 1.6409 - learning_rate: 0.0100
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.01.
# Epoch 6/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5198 - loss: 1.6390
# Epoch 6: val_accuracy did not improve from 0.53000
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.5198 - loss: 1.6389 - val_accuracy: 0.5166 - val_loss: 1.6956 - learning_rate: 0.0100
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.009987820251299122.
# Epoch 7/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5493 - loss: 1.5868
# Epoch 7: val_accuracy improved from 0.53000 to 0.54820, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.5493 - loss: 1.5867 - val_accuracy: 0.5482 - val_loss: 1.6089 - learning_rate: 0.0100
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.009951340343707852.
# Epoch 8/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5792 - loss: 1.5275
# Epoch 8: val_accuracy did not improve from 0.54820
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.5792 - loss: 1.5274 - val_accuracy: 0.5098 - val_loss: 1.7913 - learning_rate: 0.0100
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.009890738003669028.
# Epoch 9/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5986 - loss: 1.4862
# Epoch 9: val_accuracy improved from 0.54820 to 0.59940, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.5986 - loss: 1.4862 - val_accuracy: 0.5994 - val_loss: 1.4877 - learning_rate: 0.0099
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.009806308479691595.
# Epoch 10/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6245 - loss: 1.4423
# Epoch 10: val_accuracy did not improve from 0.59940
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6245 - loss: 1.4423 - val_accuracy: 0.5840 - val_loss: 1.5709 - learning_rate: 0.0098
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.009698463103929543.
# Epoch 11/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6358 - loss: 1.4069
# Epoch 11: val_accuracy improved from 0.59940 to 0.61960, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.6358 - loss: 1.4069 - val_accuracy: 0.6196 - val_loss: 1.5188 - learning_rate: 0.0097
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.009567727288213004.
# Epoch 12/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6567 - loss: 1.3714
# Epoch 12: val_accuracy did not improve from 0.61960
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6567 - loss: 1.3715 - val_accuracy: 0.5988 - val_loss: 1.5409 - learning_rate: 0.0096
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.009414737964294635.
# Epoch 13/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6645 - loss: 1.3505
# Epoch 13: val_accuracy improved from 0.61960 to 0.62920, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.6645 - loss: 1.3505 - val_accuracy: 0.6292 - val_loss: 1.5582 - learning_rate: 0.0094
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.00924024048078213.
# Epoch 14/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6743 - loss: 1.3257
# Epoch 14: val_accuracy improved from 0.62920 to 0.64760, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 38s 108ms/step - accuracy: 0.6743 - loss: 1.3257 - val_accuracy: 0.6476 - val_loss: 1.4713 - learning_rate: 0.0092
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.009045084971874737.
# Epoch 15/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6873 - loss: 1.2976
# Epoch 15: val_accuracy did not improve from 0.64760
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.6873 - loss: 1.2976 - val_accuracy: 0.6450 - val_loss: 1.4890 - learning_rate: 0.0090
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.00883022221559489.
# Epoch 16/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6985 - loss: 1.2703
# Epoch 16: val_accuracy improved from 0.64760 to 0.68760, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.6985 - loss: 1.2703 - val_accuracy: 0.6876 - val_loss: 1.3340 - learning_rate: 0.0088
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.008596699001693256.
# Epoch 17/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7075 - loss: 1.2575
# Epoch 17: val_accuracy did not improve from 0.68760
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.7075 - loss: 1.2575 - val_accuracy: 0.6830 - val_loss: 1.3765 - learning_rate: 0.0086
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.008345653031794291.
# Epoch 18/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7134 - loss: 1.2362
# Epoch 18: val_accuracy improved from 0.68760 to 0.69660, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.7134 - loss: 1.2362 - val_accuracy: 0.6966 - val_loss: 1.3204 - learning_rate: 0.0083
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.008078307376628291.
# Epoch 19/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7236 - loss: 1.2253
# Epoch 19: val_accuracy did not improve from 0.69660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.7236 - loss: 1.2252 - val_accuracy: 0.6944 - val_loss: 1.3615 - learning_rate: 0.0081
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.007795964517353734.
# Epoch 20/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7312 - loss: 1.2057
# Epoch 20: val_accuracy improved from 0.69660 to 0.74840, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.7312 - loss: 1.2057 - val_accuracy: 0.7484 - val_loss: 1.1952 - learning_rate: 0.0078
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0075.
# Epoch 21/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7385 - loss: 1.1886
# Epoch 21: val_accuracy did not improve from 0.74840
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.7385 - loss: 1.1886 - val_accuracy: 0.7042 - val_loss: 1.2990 - learning_rate: 0.0075
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.007191855733945388.
# Epoch 22/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7446 - loss: 1.1752
# Epoch 22: val_accuracy did not improve from 0.74840
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.7446 - loss: 1.1752 - val_accuracy: 0.6784 - val_loss: 1.4041 - learning_rate: 0.0072
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.00687303296707956.
# Epoch 23/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7544 - loss: 1.1541
# Epoch 23: val_accuracy did not improve from 0.74840
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.7544 - loss: 1.1541 - val_accuracy: 0.6928 - val_loss: 1.3622 - learning_rate: 0.0069
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.006545084971874737.
# Epoch 24/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7589 - loss: 1.1405
# Epoch 24: val_accuracy improved from 0.74840 to 0.75960, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.7589 - loss: 1.1405 - val_accuracy: 0.7596 - val_loss: 1.1671 - learning_rate: 0.0065
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.006209609477998339.
# Epoch 25/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7640 - loss: 1.1329
# Epoch 25: val_accuracy did not improve from 0.75960
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.7640 - loss: 1.1329 - val_accuracy: 0.7044 - val_loss: 1.3811 - learning_rate: 0.0062
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.005868240888334653.
# Epoch 26/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7673 - loss: 1.1195
# Epoch 26: val_accuracy did not improve from 0.75960
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.7673 - loss: 1.1195 - val_accuracy: 0.7510 - val_loss: 1.2072 - learning_rate: 0.0059
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.0055226423163382676.
# Epoch 27/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7779 - loss: 1.1047
# Epoch 27: val_accuracy did not improve from 0.75960
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.7779 - loss: 1.1047 - val_accuracy: 0.7508 - val_loss: 1.1993 - learning_rate: 0.0055
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.005174497483512506.
# Epoch 28/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7711 - loss: 1.1116
# Epoch 28: val_accuracy did not improve from 0.75960
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.7712 - loss: 1.1116 - val_accuracy: 0.7558 - val_loss: 1.2029 - learning_rate: 0.0052
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.004825502516487497.
# Epoch 29/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7829 - loss: 1.0919
# Epoch 29: val_accuracy did not improve from 0.75960
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.002412751317024231.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.7829 - loss: 1.0919 - val_accuracy: 0.7118 - val_loss: 1.3460 - learning_rate: 0.0048
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.0044773576836617335.
# Epoch 30/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7890 - loss: 1.0788
# Epoch 30: val_accuracy improved from 0.75960 to 0.76360, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.7890 - loss: 1.0788 - val_accuracy: 0.7636 - val_loss: 1.1923 - learning_rate: 0.0045
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.0041317591116653484.
# Epoch 31/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7905 - loss: 1.0730
# Epoch 31: val_accuracy improved from 0.76360 to 0.77920, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.7905 - loss: 1.0730 - val_accuracy: 0.7792 - val_loss: 1.1606 - learning_rate: 0.0041
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.003790390522001661.
# Epoch 32/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7914 - loss: 1.0697
# Epoch 32: val_accuracy improved from 0.77920 to 0.78880, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.7914 - loss: 1.0697 - val_accuracy: 0.7888 - val_loss: 1.1175 - learning_rate: 0.0038
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.003454915028125263.
# Epoch 33/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8002 - loss: 1.0521
# Epoch 33: val_accuracy improved from 0.78880 to 0.79180, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.8002 - loss: 1.0521 - val_accuracy: 0.7918 - val_loss: 1.1017 - learning_rate: 0.0035
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.00312696703292044.
# Epoch 34/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8018 - loss: 1.0459
# Epoch 34: val_accuracy did not improve from 0.79180
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.8018 - loss: 1.0459 - val_accuracy: 0.7618 - val_loss: 1.2156 - learning_rate: 0.0031
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.0028081442660546126.
# Epoch 35/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8059 - loss: 1.0357
# Epoch 35: val_accuracy did not improve from 0.79180
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.8060 - loss: 1.0357 - val_accuracy: 0.7524 - val_loss: 1.2265 - learning_rate: 0.0028
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.0025000000000000014.
# Epoch 36/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8061 - loss: 1.0373
# Epoch 36: val_accuracy improved from 0.79180 to 0.79700, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.8061 - loss: 1.0373 - val_accuracy: 0.7970 - val_loss: 1.1008 - learning_rate: 0.0025
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.0022040354826462667.
# Epoch 37/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8112 - loss: 1.0260
# Epoch 37: val_accuracy improved from 0.79700 to 0.80120, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.8112 - loss: 1.0260 - val_accuracy: 0.8012 - val_loss: 1.0882 - learning_rate: 0.0022
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.0019216926233717087.
# Epoch 38/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8189 - loss: 1.0145
# Epoch 38: val_accuracy improved from 0.80120 to 0.80380, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.8189 - loss: 1.0145 - val_accuracy: 0.8038 - val_loss: 1.0686 - learning_rate: 0.0019
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.0016543469682057089.
# Epoch 39/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8171 - loss: 1.0162
# Epoch 39: val_accuracy did not improve from 0.80380
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.8171 - loss: 1.0162 - val_accuracy: 0.7796 - val_loss: 1.1633 - learning_rate: 0.0017
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.001403300998306744.
# Epoch 40/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8210 - loss: 1.0050
# Epoch 40: val_accuracy improved from 0.80380 to 0.81160, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.8210 - loss: 1.0050 - val_accuracy: 0.8116 - val_loss: 1.0572 - learning_rate: 0.0014
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0011697777844051104.
# Epoch 41/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8238 - loss: 1.0011
# Epoch 41: val_accuracy did not improve from 0.81160
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.8238 - loss: 1.0011 - val_accuracy: 0.8014 - val_loss: 1.0774 - learning_rate: 0.0012
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.0009549150281252633.
# Epoch 42/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8233 - loss: 1.0033
# Epoch 42: val_accuracy did not improve from 0.81160
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.8233 - loss: 1.0033 - val_accuracy: 0.8018 - val_loss: 1.0879 - learning_rate: 9.5492e-04
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.0007597595192178702.
# Epoch 43/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8212 - loss: 1.0032
# Epoch 43: val_accuracy did not improve from 0.81160
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.8212 - loss: 1.0031 - val_accuracy: 0.8050 - val_loss: 1.0865 - learning_rate: 7.5976e-04
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.0005852620357053662.
# Epoch 44/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8249 - loss: 0.9962
# Epoch 44: val_accuracy improved from 0.81160 to 0.81500, saving model to ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.8249 - loss: 0.9962 - val_accuracy: 0.8150 - val_loss: 1.0500 - learning_rate: 5.8526e-04
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.00043227271178699624.
# Epoch 45/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8260 - loss: 0.9930
# Epoch 45: val_accuracy did not improve from 0.81500
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.8260 - loss: 0.9930 - val_accuracy: 0.8112 - val_loss: 1.0565 - learning_rate: 4.3227e-04
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.00030153689607045843.
# Epoch 46/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8260 - loss: 0.9968
# Epoch 46: val_accuracy did not improve from 0.81500
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.8260 - loss: 0.9968 - val_accuracy: 0.8080 - val_loss: 1.0723 - learning_rate: 3.0154e-04
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.00019369152030840664.
# Epoch 47/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8278 - loss: 0.9894
# Epoch 47: val_accuracy did not improve from 0.81500
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 37s 104ms/step - accuracy: 0.8278 - loss: 0.9894 - val_accuracy: 0.8054 - val_loss: 1.0789 - learning_rate: 1.9369e-04
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.00010926199633097155.
# Epoch 48/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8301 - loss: 0.9835
# Epoch 48: val_accuracy did not improve from 0.81500
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.8301 - loss: 0.9835 - val_accuracy: 0.8086 - val_loss: 1.0746 - learning_rate: 1.0926e-04
#
# Epoch 49: LearningRateScheduler setting learning rate to 4.865965629214875e-05.
# Epoch 49/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8296 - loss: 0.9857
# Epoch 49: val_accuracy did not improve from 0.81500
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 2.4329827283509076e-05.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.8296 - loss: 0.9857 - val_accuracy: 0.8060 - val_loss: 1.0721 - learning_rate: 4.8660e-05
#
# Epoch 50: LearningRateScheduler setting learning rate to 1.2179748700879012e-05.
# Epoch 50/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8313 - loss: 0.9838
# Epoch 50: val_accuracy did not improve from 0.81500
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.8313 - loss: 0.9838 - val_accuracy: 0.8064 - val_loss: 1.0772 - learning_rate: 1.2180e-05
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.0.
# Epoch 51/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8308 - loss: 0.9846
# Epoch 51: val_accuracy did not improve from 0.81500
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.8308 - loss: 0.9846 - val_accuracy: 0.8062 - val_loss: 1.0779 - learning_rate: 0.0000e+00
#
# Epoch 52: LearningRateScheduler setting learning rate to 1.2179748700878457e-05.
# Epoch 52/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8282 - loss: 0.9868
# Epoch 52: val_accuracy did not improve from 0.81500
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.8282 - loss: 0.9868 - val_accuracy: 0.8064 - val_loss: 1.0749 - learning_rate: 1.2180e-05
#
# Epoch 53: LearningRateScheduler setting learning rate to 4.865965629214875e-05.
# Epoch 53/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8318 - loss: 0.9824
# Epoch 53: val_accuracy did not improve from 0.81500
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.8318 - loss: 0.9824 - val_accuracy: 0.8074 - val_loss: 1.0734 - learning_rate: 4.8660e-05
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.00010926199633097155.
# Epoch 54/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8299 - loss: 0.9863
# Epoch 54: val_accuracy did not improve from 0.81500
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 5.463099660119042e-05.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.8299 - loss: 0.9863 - val_accuracy: 0.8068 - val_loss: 1.0746 - learning_rate: 1.0926e-04
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.00019369152030840553.
# Epoch 55/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8286 - loss: 0.9896
# Epoch 55: val_accuracy did not improve from 0.81500
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.8286 - loss: 0.9896 - val_accuracy: 0.8128 - val_loss: 1.0549 - learning_rate: 1.9369e-04
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.0003015368960704579.
# Epoch 56/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8288 - loss: 0.9857
# Epoch 56: val_accuracy did not improve from 0.81500
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.8288 - loss: 0.9857 - val_accuracy: 0.8068 - val_loss: 1.0743 - learning_rate: 3.0154e-04
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.00043227271178699456.
# Epoch 57/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8341 - loss: 0.9811
# Epoch 57: val_accuracy did not improve from 0.81500
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.8341 - loss: 0.9811 - val_accuracy: 0.8060 - val_loss: 1.0755 - learning_rate: 4.3227e-04
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0005852620357053657.
# Epoch 58/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8330 - loss: 0.9833
# Epoch 58: val_accuracy did not improve from 0.81500
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.8330 - loss: 0.9833 - val_accuracy: 0.8096 - val_loss: 1.0706 - learning_rate: 5.8526e-04
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.0007597595192178697.
# Epoch 59/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8268 - loss: 0.9922
# Epoch 59: val_accuracy did not improve from 0.81500
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.0003798797552008182.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.8268 - loss: 0.9922 - val_accuracy: 0.8074 - val_loss: 1.0786 - learning_rate: 7.5976e-04
# Epoch 59: early stopping
# Restoring model weights from the end of the best epoch: 44.
#
# Training completed in 35.74 minutes
#
# Evaluating model on test set...
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8134 - loss: 1.0561
# Test accuracy: 0.8095
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     airplane       0.84      0.81      0.83      1000
#   automobile       0.93      0.92      0.92      1000
#         bird       0.83      0.62      0.71      1000
#          cat       0.75      0.57      0.65      1000
#         deer       0.76      0.77      0.77      1000
#          dog       0.76      0.77      0.76      1000
#         frog       0.67      0.95      0.78      1000
#        horse       0.85      0.84      0.85      1000
#         ship       0.91      0.91      0.91      1000
#        truck       0.85      0.94      0.89      1000
#
#     accuracy                           0.81     10000
#    macro avg       0.81      0.81      0.81     10000
# weighted avg       0.81      0.81      0.81     10000
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# === Fine-tuning on CIFAR-100 ===
# Using best model from ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras for fine-tuning
# Training data range: -1.8959 to 2.0253
# Validation data range: -1.8959 to 2.0253
# Test data range: -1.8959 to 2.0253
# Dataset: cifar100
# Training set shape: (45000, 32, 32, 3), (45000, 100)
# Validation set shape: (5000, 32, 32, 3), (5000, 100)
# Test set shape: (10000, 32, 32, 3), (10000, 100)
# Data Statistics:
# Training samples: 45000
# Validation samples: 5000
# Test samples: 10000
# Data range: -1.8959 to 2.0253
# Loading model from ./CIFAR_CNN_Improved/best_model_cifar10_improved.keras for fine-tuning
# Replacing output layer to match 100 classes
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 32, 32, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ initial_conv (Conv2D)     │ (None, 32, 32, 64)     │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ initial_bn                │ (None, 32, 32, 64)     │            256 │ initial_conv[0][0]     │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ initial_relu (Activation) │ (None, 32, 32, 64)     │              0 │ initial_bn[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_bn1           │ (None, 32, 32, 64)     │            256 │ initial_relu[0][0]     │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_relu1         │ (None, 32, 32, 64)     │              0 │ block1_res1_bn1[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_conv1         │ (None, 32, 32, 64)     │         36,928 │ block1_res1_relu1[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_bn2           │ (None, 32, 32, 64)     │            256 │ block1_res1_conv1[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_relu2         │ (None, 32, 32, 64)     │              0 │ block1_res1_bn2[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_conv2         │ (None, 32, 32, 64)     │         36,928 │ block1_res1_relu2[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_res1_add (Add)     │ (None, 32, 32, 64)     │              0 │ initial_relu[0][0],    │
# │                           │                        │                │ block1_res1_conv2[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1_dropout (Dropout)  │ (None, 32, 32, 64)     │              0 │ block1_res1_add[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_bn1           │ (None, 32, 32, 64)     │            256 │ block1_dropout[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_relu1         │ (None, 32, 32, 64)     │              0 │ block2_res1_bn1[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_conv1         │ (None, 16, 16, 128)    │         73,856 │ block2_res1_relu1[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_bn2           │ (None, 16, 16, 128)    │            512 │ block2_res1_conv1[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_relu2         │ (None, 16, 16, 128)    │              0 │ block2_res1_bn2[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_shortcut_conv │ (None, 16, 16, 128)    │          8,320 │ block1_dropout[0][0]   │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_conv2         │ (None, 16, 16, 128)    │        147,584 │ block2_res1_relu2[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_res1_add (Add)     │ (None, 16, 16, 128)    │              0 │ block2_res1_shortcut_… │
# │                           │                        │                │ block2_res1_conv2[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2_dropout (Dropout)  │ (None, 16, 16, 128)    │              0 │ block2_res1_add[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_res1_bn1           │ (None, 16, 16, 128)    │            512 │ block2_dropout[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_res1_relu1         │ (None, 16, 16, 128)    │              0 │ block3_res1_bn1[0][0]  │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_res1_conv1         │ (None, 8, 8, 256)      │        295,168 │ block3_res1_relu1[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3_res1_bn2           │ (None, 8, 8, 256)      │          1,024 │ block3_res1_conv1[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.5977 - loss: 2.1402 - val_accuracy: 0.5712 - val_loss: 2.2766 - learning_rate: 9.5492e-04
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.0007597595192178702.
# Epoch 43/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5917 - loss: 2.1430
# Epoch 43: val_accuracy did not improve from 0.57120
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.5917 - loss: 2.1429 - val_accuracy: 0.5676 - val_loss: 2.2823 - learning_rate: 7.5976e-04
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.0005852620357053662.
# Epoch 44/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6018 - loss: 2.1229
# Epoch 44: val_accuracy did not improve from 0.57120
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6018 - loss: 2.1229 - val_accuracy: 0.5626 - val_loss: 2.3089 - learning_rate: 5.8526e-04
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.00043227271178699624.
# Epoch 45/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5996 - loss: 2.1294
# Epoch 45: val_accuracy did not improve from 0.57120
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.5996 - loss: 2.1294 - val_accuracy: 0.5682 - val_loss: 2.2743 - learning_rate: 4.3227e-04
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.00030153689607045843.
# Epoch 46/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6017 - loss: 2.1217
# Epoch 46: val_accuracy did not improve from 0.57120
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.6017 - loss: 2.1217 - val_accuracy: 0.5696 - val_loss: 2.2826 - learning_rate: 3.0154e-04
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.00019369152030840664.
# Epoch 47/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6047 - loss: 2.1240
# Epoch 47: val_accuracy did not improve from 0.57120
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.6047 - loss: 2.1240 - val_accuracy: 0.5696 - val_loss: 2.2817 - learning_rate: 1.9369e-04
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.00010926199633097155.
# Epoch 48/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6039 - loss: 2.1204
# Epoch 48: val_accuracy did not improve from 0.57120
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6039 - loss: 2.1203 - val_accuracy: 0.5658 - val_loss: 2.2872 - learning_rate: 1.0926e-04
#
# Epoch 49: LearningRateScheduler setting learning rate to 4.865965629214875e-05.
# Epoch 49/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6003 - loss: 2.1174
# Epoch 49: val_accuracy did not improve from 0.57120
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6003 - loss: 2.1174 - val_accuracy: 0.5698 - val_loss: 2.2842 - learning_rate: 4.8660e-05
#
# Epoch 50: LearningRateScheduler setting learning rate to 1.2179748700879012e-05.
# Epoch 50/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6010 - loss: 2.1256
# Epoch 50: val_accuracy did not improve from 0.57120
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 6.089874204917578e-06.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.6010 - loss: 2.1256 - val_accuracy: 0.5698 - val_loss: 2.2805 - learning_rate: 1.2180e-05
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.0.
# Epoch 51/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6054 - loss: 2.1226
# Epoch 51: val_accuracy did not improve from 0.57120
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6055 - loss: 2.1226 - val_accuracy: 0.5696 - val_loss: 2.2840 - learning_rate: 0.0000e+00
#
# Epoch 52: LearningRateScheduler setting learning rate to 1.2179748700878457e-05.
# Epoch 52/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6051 - loss: 2.1145
# Epoch 52: val_accuracy did not improve from 0.57120
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6051 - loss: 2.1145 - val_accuracy: 0.5700 - val_loss: 2.2797 - learning_rate: 1.2180e-05
#
# Epoch 53: LearningRateScheduler setting learning rate to 4.865965629214875e-05.
# Epoch 53/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6037 - loss: 2.1220
# Epoch 53: val_accuracy did not improve from 0.57120
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6037 - loss: 2.1220 - val_accuracy: 0.5684 - val_loss: 2.2797 - learning_rate: 4.8660e-05
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.00010926199633097155.
# Epoch 54/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6103 - loss: 2.1148
# Epoch 54: val_accuracy improved from 0.57120 to 0.57240, saving model to ./CIFAR_CNN_Improved/best_model_cifar100_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.6103 - loss: 2.1148 - val_accuracy: 0.5724 - val_loss: 2.2770 - learning_rate: 1.0926e-04
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.00019369152030840553.
# Epoch 55/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5991 - loss: 2.1190
# Epoch 55: val_accuracy did not improve from 0.57240
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 9.684576070867479e-05.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.5991 - loss: 2.1190 - val_accuracy: 0.5712 - val_loss: 2.2775 - learning_rate: 1.9369e-04
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.0003015368960704579.
# Epoch 56/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6014 - loss: 2.1275
# Epoch 56: val_accuracy did not improve from 0.57240
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.6014 - loss: 2.1275 - val_accuracy: 0.5698 - val_loss: 2.2820 - learning_rate: 3.0154e-04
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.00043227271178699456.
# Epoch 57/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6015 - loss: 2.1184
# Epoch 57: val_accuracy improved from 0.57240 to 0.57340, saving model to ./CIFAR_CNN_Improved/best_model_cifar100_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 38s 108ms/step - accuracy: 0.6015 - loss: 2.1183 - val_accuracy: 0.5734 - val_loss: 2.2649 - learning_rate: 4.3227e-04
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0005852620357053657.
# Epoch 58/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6014 - loss: 2.1222
# Epoch 58: val_accuracy did not improve from 0.57340
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.6014 - loss: 2.1222 - val_accuracy: 0.5698 - val_loss: 2.2775 - learning_rate: 5.8526e-04
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.0007597595192178697.
# Epoch 59/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6065 - loss: 2.1206
# Epoch 59: val_accuracy did not improve from 0.57340
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6065 - loss: 2.1206 - val_accuracy: 0.5600 - val_loss: 2.3154 - learning_rate: 7.5976e-04
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.0009549150281252622.
# Epoch 60/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6002 - loss: 2.1225
# Epoch 60: val_accuracy did not improve from 0.57340
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6002 - loss: 2.1225 - val_accuracy: 0.5604 - val_loss: 2.3069 - learning_rate: 9.5492e-04
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.00116977778440511.
# Epoch 61/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6019 - loss: 2.1303
# Epoch 61: val_accuracy did not improve from 0.57340
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6019 - loss: 2.1303 - val_accuracy: 0.5598 - val_loss: 2.3283 - learning_rate: 0.0012
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.0014033009983067447.
# Epoch 62/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6002 - loss: 2.1245
# Epoch 62: val_accuracy did not improve from 0.57340
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 0.0007016505114734173.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6002 - loss: 2.1245 - val_accuracy: 0.5618 - val_loss: 2.2922 - learning_rate: 0.0014
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.0016543469682057078.
# Epoch 63/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5992 - loss: 2.1233
# Epoch 63: val_accuracy improved from 0.57340 to 0.57660, saving model to ./CIFAR_CNN_Improved/best_model_cifar100_improved.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.5992 - loss: 2.1233 - val_accuracy: 0.5766 - val_loss: 2.2590 - learning_rate: 0.0017
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.0019216926233717097.
# Epoch 64/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6024 - loss: 2.1226
# Epoch 64: val_accuracy did not improve from 0.57660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 37s 104ms/step - accuracy: 0.6024 - loss: 2.1226 - val_accuracy: 0.5664 - val_loss: 2.3199 - learning_rate: 0.0019
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.0022040354826462637.
# Epoch 65/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5982 - loss: 2.1216
# Epoch 65: val_accuracy did not improve from 0.57660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.5982 - loss: 2.1216 - val_accuracy: 0.5728 - val_loss: 2.2921 - learning_rate: 0.0022
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.002499999999999998.
# Epoch 66/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6022 - loss: 2.1215
# Epoch 66: val_accuracy did not improve from 0.57660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.6021 - loss: 2.1215 - val_accuracy: 0.5592 - val_loss: 2.3092 - learning_rate: 0.0025
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.0028081442660546113.
# Epoch 67/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5966 - loss: 2.1290
# Epoch 67: val_accuracy did not improve from 0.57660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.5966 - loss: 2.1290 - val_accuracy: 0.5566 - val_loss: 2.3266 - learning_rate: 0.0028
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.0031269670329204385.
# Epoch 68/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5981 - loss: 2.1256
# Epoch 68: val_accuracy did not improve from 0.57660
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 0.0015634834999218583.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.5981 - loss: 2.1256 - val_accuracy: 0.5470 - val_loss: 2.3710 - learning_rate: 0.0031
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.0034549150281252623.
# Epoch 69/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6001 - loss: 2.1220
# Epoch 69: val_accuracy did not improve from 0.57660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.6001 - loss: 2.1220 - val_accuracy: 0.5536 - val_loss: 2.3499 - learning_rate: 0.0035
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.003790390522001661.
# Epoch 70/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6013 - loss: 2.1250
# Epoch 70: val_accuracy did not improve from 0.57660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6013 - loss: 2.1250 - val_accuracy: 0.5630 - val_loss: 2.3039 - learning_rate: 0.0038
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.0041317591116653484.
# Epoch 71/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5974 - loss: 2.1365
# Epoch 71: val_accuracy did not improve from 0.57660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 37s 105ms/step - accuracy: 0.5974 - loss: 2.1365 - val_accuracy: 0.5658 - val_loss: 2.2805 - learning_rate: 0.0041
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.0044773576836617335.
# Epoch 72/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6002 - loss: 2.1220
# Epoch 72: val_accuracy did not improve from 0.57660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6001 - loss: 2.1221 - val_accuracy: 0.5428 - val_loss: 2.3941 - learning_rate: 0.0045
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.004825502516487491.
# Epoch 73/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6013 - loss: 2.1154
# Epoch 73: val_accuracy did not improve from 0.57660
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 0.002412751317024231.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.6013 - loss: 2.1154 - val_accuracy: 0.5240 - val_loss: 2.4855 - learning_rate: 0.0048
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.005174497483512507.
# Epoch 74/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6012 - loss: 2.1158
# Epoch 74: val_accuracy did not improve from 0.57660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.6012 - loss: 2.1158 - val_accuracy: 0.5508 - val_loss: 2.3589 - learning_rate: 0.0052
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.005522642316338266.
# Epoch 75/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6011 - loss: 2.1178
# Epoch 75: val_accuracy did not improve from 0.57660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 36s 101ms/step - accuracy: 0.6011 - loss: 2.1178 - val_accuracy: 0.5280 - val_loss: 2.4327 - learning_rate: 0.0055
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.005868240888334651.
# Epoch 76/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6065 - loss: 2.1156
# Epoch 76: val_accuracy did not improve from 0.57660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6065 - loss: 2.1156 - val_accuracy: 0.5720 - val_loss: 2.2886 - learning_rate: 0.0059
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.006209609477998337.
# Epoch 77/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6019 - loss: 2.1085
# Epoch 77: val_accuracy did not improve from 0.57660
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 101ms/step - accuracy: 0.6019 - loss: 2.1086 - val_accuracy: 0.5074 - val_loss: 2.5593 - learning_rate: 0.0062
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.0065450849718747366.
# Epoch 78/100
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6050 - loss: 2.1051
# Epoch 78: val_accuracy did not improve from 0.57660
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 0.0032725424971431494.
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 35s 100ms/step - accuracy: 0.6050 - loss: 2.1052 - val_accuracy: 0.4928 - val_loss: 2.5752 - learning_rate: 0.0065
# Epoch 78: early stopping
# Restoring model weights from the end of the best epoch: 63.
#
# Training completed in 47.13 minutes
#
# Evaluating model on test set...
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5746 - loss: 2.2755
# Test accuracy: 0.5717
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     mountain       0.81      0.87      0.84       100
#       forest       0.88      0.60      0.71       100
#         seal       0.88      0.21      0.34       100
#     mushroom       0.92      0.55      0.69       100
#          sea       0.86      0.78      0.82       100
#        tulip       0.84      0.41      0.55       100
#        camel       0.82      0.47      0.60       100
#    butterfly       0.79      0.56      0.65       100
#        cloud       0.94      0.75      0.83       100
#        apple       1.00      0.87      0.93       100
#        skunk       0.99      0.77      0.87       100
#    streetcar       0.98      0.79      0.87       100
#       rocket       0.93      0.71      0.81       100
#         lamp       0.93      0.37      0.53       100
#         lion       0.86      0.42      0.56       100
#         wolf       0.98      0.52      0.68       100
#         rose       0.82      0.70      0.76       100
#       orange       0.97      0.86      0.91       100
#     dinosaur       0.80      0.47      0.59       100
#   chimpanzee       0.97      0.65      0.78       100
#
#    micro avg       0.90      0.62      0.73      2000
#    macro avg       0.90      0.62      0.72      2000
# weighted avg       0.90      0.62      0.72      2000
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training and evaluation completed!
